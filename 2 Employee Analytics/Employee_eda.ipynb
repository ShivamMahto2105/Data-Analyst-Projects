# %% [markdown]
# # Exploratory Data Analysis

# %%
# Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the dataset

# %%
df1 = pd.read_csv('departments.csv')

# %%
df2 = pd.read_csv('employees.csv')

# %%
# Top 5 Rows of Data

# %%
df1.head()
# Out:
#    dept_id  dept_name
# 0        1         HR
# 1        2    Finance
# 2        3         IT
# 3        4  Marketing
# 4        5      Sales

# %%
df2.head()
# Out:
#    emp_id      emp_name  dept_id job_level  gender  experience_years  \
# 0       1   Vikas Yadav        5       Mid    Male                 5
# 1       2  Varun Bansal        1       Mid  Female                 9
# 2       3   Ritu Saxena        2       Mid  Female                 3
# 3       4     Arjun Das        2   Manager  Female                 9
# 4       5   Pooja Patel        4   Manager    Male                 1
#
#     location  salary  bonus attrition
# 0  Bangalore   71638  29284       Yes
# 1  Bangalore  137111  27020        No
# 2     Mumbai  103519  11772       Yes
# 3     Mumbai  137345   7348        No
# 4      Delhi  130311  24135       Yes

# %%
# Last 5 Rows of Data for Employees

# %%
df2.tail()
# Out:
#       emp_id     emp_name  dept_id job_level  gender  experience_years  \
# 9995    9996  Rahul Verma        1    Junior  Female                11
# 9996    9997    Arjun Das        3       Mid    Male                13
# 9997    9998  Rahul Verma        2       Mid    Male                13
# 9998    9999  Amit Sharma        5   Manager    Male                 9
# 9999   10000  Rahul Verma        3       Mid    Male                12
#
#        location  salary  bonus attrition
# 9995     Mumbai   86732  25185        No
# 9996     Mumbai  113074  10869        No
# 9997      Delhi  144273  15798        No
# 9998  Bangalore   86167  17225       Yes
# 9999      Delhi  126004   5344        No

# %%
# Information of the Data(Employees)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   emp_id            10000 non-null  int64
#  1   emp_name          10000 non-null  object
#  2   dept_id           10000 non-null  int64
#  3   job_level         10000 non-null  object
#  4   gender            10000 non-null  object
#  5   experience_years  10000 non-null  int64
#  6   location          10000 non-null  object
#  7   salary            10000 non-null  int64
#  8   bonus             10000 non-null  int64
#  9   attrition         10000 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 781.4+ KB

# %%
# Check the summary statictics of all the column for Employees

# %%
df2.describe()
# Out:
#             emp_id       dept_id  experience_years        salary         bonus
# count  10000.00000  10000.000000       10000.00000   10000.00000  10000.000000
# mean    5000.50000      2.999000           7.58530   89507.79630  17553.102600
# std     2886.89568      1.418309           4.00309   34584.71849   7255.047079
# min        1.00000      1.000000           1.00000   30002.00000   5004.000000
# 25%     2500.75000      2.000000           4.00000   59274.50000  11145.000000
# 50%     5000.50000      3.000000           8.00000   88854.50000  17627.000000
# 75%     7500.25000      4.000000          11.00000  119266.50000  23885.750000
# max    10000.00000      5.000000          14.00000  149980.00000  29993.000000

# %%
# df.describe() default only numerical column statitics.if we want all column statitics summary then do df.describe(include = 'all')

# %%
# Check the missing values for Employees

# %%
df2.isnull().sum()
# Out:
# emp_id              0
# emp_name            0
# dept_id             0
# job_level           0
# gender              0
# experience_years    0
# location            0
# salary              0
# bonus               0
# attrition           0
# dtype: int64

# %%
#Unique Values (Categorical) for Employees

# %%
df2['department'] if 'department' in df2.columns else "Use dept_id instead"
# Out:
# 'Use dept_id instead'

# %%
df2['job_level'].value_counts()
# Out:
# job_level
# Manager    2574
# Senior     2506
# Mid        2467
# Junior     2453
# Name: count, dtype: int64

# %%
df2['gender'].value_counts()
# Out:
# gender
# Male      5126
# Female    4874
# Name: count, dtype: int64

# %%
df2['attrition'].value_counts()
# Out:
# attrition
# No     8038
# Yes    1962
# Name: count, dtype: int64

# %%
#Mergae With Department Table

# %%
merged = df2.merge(df1, on="dept_id", how="left")

# %%
print(merged.head())
# Out:
#    emp_id      emp_name  dept_id job_level  gender  experience_years  \
# 0       1   Vikas Yadav        5       Mid    Male                 5
# 1       2  Varun Bansal        1       Mid  Female                 9
# 2       3   Ritu Saxena        2       Mid  Female                 3
# 3       4     Arjun Das        2   Manager  Female                 9
# 4       5   Pooja Patel        4   Manager    Male                 1
#
#     location  salary  bonus attrition  dept_name
# 0  Bangalore   71638  29284       Yes      Sales
# 1  Bangalore  137111  27020        No         HR
# 2     Mumbai  103519  11772       Yes    Finance
# 3     Mumbai  137345   7348        No    Finance
# 4      Delhi  130311  24135       Yes  Marketing

# %%
# Salary Analysis

# %%
print(round(merged.groupby('dept_name')['salary'].mean()))
# Out:
# dept_name
# Finance      90308.0
# HR           88567.0
# IT           89071.0
# Marketing    89776.0
# Sales        89775.0
# Name: salary, dtype: float64

# %%
# Gender Pay Gap

# %%
print(round(merged.groupby('gender')['salary'].mean()))
# Out:
# gender
# Female    88993.0
# Male      89997.0
# Name: salary, dtype: float64

# %%
''' Check all Columns All Columns Should be in snake cast : Naming Convention in programming where spaces between words are replaced with an underscore(_) and all the 
letters are typically in lowercase. Make them more readable'''
# Out:
# ' Check all Columns All Columns Should be in snake cast : Naming Convention in programming where spaces between words are replaced with an underscore(_) and all the \nletters are typically in lowercase. Make them more readable'

# %%
df1.columns
# Out:
# Index(['dept_id', 'dept_name'], dtype='object')

# %%
df2.columns
# Out:
# Index(['emp_id', 'emp_name', 'dept_id', 'job_level', 'gender',
#        'experience_years', 'location', 'salary', 'bonus', 'attrition'],
#       dtype='object')

# %%
# All Columns are good and in snake cast so we proceed next part.

# %% [markdown]
# # Data Visualization

# %%
# Salary distribution

# %%
merged['salary'].hist()
plt.title("Salary Distribution")
plt.show()

# %%
# Avg salary by department

# %%
merged.groupby('dept_name')['salary'].mean().plot(kind='bar')
plt.title("Avg Salary by Department")
plt.show()

# %%
# Connecting the jupyter Notebook to Microsoft SQl For Data Transmission

# %%
from sqlalchemy import create_engine
import pandas as pd

# Connection details
server = "SHIVAM-KUMAR-MA\\SQLEXPRESS"
database = "MyDatabase"

engine = create_engine(
    f"mssql+pyodbc://@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

# Load CSV files
employees_df = pd.read_csv("employees.csv")
departments_df = pd.read_csv("departments.csv")

# Load to SQL (2 tables)
departments_df.to_sql("departments", engine, if_exists="append", index=False)
employees_df.to_sql("employees", engine, if_exists="append", index=False)

print("Both tables loaded successfully!")
# Out:
# Both tables loaded successfully!
